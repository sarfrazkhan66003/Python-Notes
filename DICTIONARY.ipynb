# %% [markdown]
# DICTONARY

# %% [markdown]
# VALUE IS STORED BY HASH VALUE
# -search  complexity is O(1)
# -python dictonary is an unordered collection of item
# -storeed in the from of key value pair
# -key should be unique and immutable , key  cannot get update (hash value se generate krte hai  isily immutable)
# -values can be mutable and duplicate , can be update
# -mutable

# %%
#empty dict
my_dict ={}
#dictonary with int key
my_dict = {1: 'abc' , 2 : 'xyz'}

#create using dict function
my_dict = dict()
my_dict = dict({(1,'abc'),(2,'xyz')})
my_dict = dict([(1,'abc'),(2,'xyz')])
my_dict = dict(((1,'abc'),(2,'xyz')))
my_dict = dict([[1,'abc'],[2,'xyz']])
my_dict = dict([[1,'abc'],(2,'xyz')])
my_dict = dict([{1,'abc'},{2,'xyz'}])#but key value is not fixed because here set 
print(my_dict)

#mixed keys
my_dict = {1: 'satish', 'age': 27 , 'address': 'gubtur'}
print(my_dict)
# Out:
# {1: 'abc', 2: 'xyz'}
# {1: 'satish', 'age': 27, 'address': 'gubtur'}

# %%
#dict acess

my_dict = {'name': 'satish', 'age': 27 , 'address': 'gubtur'}
#get name
print(my_dict['name'])
# another way of accessing key if not present it will return NONE
print(my_dict.get('address'))
# Out:
# satish
# gubtur

# %%
#update value of given key , not prent key then it will create new key -value
my_dict['name'] = 'ram'

my_dict['degree'] = 'm.tech'
print(my_dict)
# Out:
# {'name': 'ram', 'age': 27, 'address': 'gubtur', 'degree': 'm.tech'}

# %%
#key should be uniques,immutable,values could be mut,imm,duplicate.
my_dict={}
#dictionary with int keys
my_dict={1:'abc',2:'xyz'}
print(my_dict)
#dictionary with mixed keys
my_dict={'name':'satosh',1:['abc','xyz']}
print(my_dict)

#create empty dictionary using dict()
my_dict=dict()

#my_dict=dict([(1,'abc'),(2,'xyz')]) #list-tuple
#my_dict=dict(([1,'abc'],[2,'xyz'])) #tuple-list
#my_dict=dict([[1,'abc'],[2,'xyz']]) #list-list
#my_dict=dict(((1,'abc'),(2,'xyz'))) #tuple-tuple
#my_dict=dict([{1,'abc'},{2,'xyz'}]) #list-set
#my_dict=dict({(1,'abc'),(2,'xyz')}) #set-list
my_dict=dict(({1,'abc'},{2,'xyz'})) #tuple-set
print(my_dict)
# Out:
# {1: 'abc', 2: 'xyz'}
# {'name': 'satosh', 1: ['abc', 'xyz']}
# {1: 'abc', 2: 'xyz'}

# %% [markdown]
# Dict Delete or remove elemnet

# %%
#create a dictionary
my_dict = {'name': 'satish','age':27,'address':'gontur'}
#remove a particular item
print(my_dict.pop('age'))
print(my_dict)
# Out:
# 27
# {'name': 'satish', 'address': 'gontur'}

# %%
my_dict = {'name': 'satish','age':27,'address':'gontur'}
#remove an arbitarty key
my_dict.popitem()
print(my_dict)
# Out:
# {'name': 'satish', 'age': 27}

# %%
sq = {2:4,3:9,4:16,5:25}
#delete particular key
del sq[2]
print(sq)
# Out:
# {3: 9, 4: 16, 5: 25}

# %%
#remove all items
sq.clear()
print(type(sq))
print(sq)
# Out:
# <class 'dict'>
# {}

# %%
sq = {2:4,3:9,4:16}
my_dict =sq #shallow copy and alaicing copy
my_dict[7]=33
print(sq)
print(my_dict)
# Out:
# {2: 4, 3: 9, 4: 16, 7: 33}
# {2: 4, 3: 9, 4: 16, 7: 33}

# %%
sq = {2:4,3:9,4:16}
my_dict =sq.copy() #deep copy
my_dict[7]=33
print(sq)
print(my_dict)
# Out:
# {2: 4, 3: 9, 4: 16}
# {2: 4, 3: 9, 4: 16, 7: 33}

# %%
#fromkeys[sequence[,value]]-> return a new dict with keys from sequence and values.
sub = {}.fromkeys(['Math','English','Hindi'],1)
print(sub)
# Out:
# {'Math': 1, 'English': 1, 'Hindi': 1}

# %%
#return a new view of the dict item(key,value) pair of values
sub = {2:4,3:9,4:16}
print(sub.items())
# Out:
# dict_items([(2, 4), (3, 9), (4, 16)])

# %%
#return a new view of the dict key pair of values
sub = {2:4,3:9,4:16}
print(sub.keys())
# Out:
# dict_keys([2, 3, 4])

# %%
#return a new view of the dict Values pair of values
sub = {2:4,3:9,4:16}
print(sub.values())
# Out:
# dict_values([4, 9, 16])

# %%
'''Write a Python script to concatenate the following dictionaries to create a new one.

Sample Dictionary :
dic1={1:10, 2:20}
dic2={3:30, 4:40}
dic3={5:50,6:60}
Expected Result : {1: 10, 2: 20, 3: 30, 4: 40, 5: 50, 6: 60}'''
dic1={1:10, 2:20}
dic2={3:30, 4:40}
dic3={5:50, 6:60}
dic4 = {}
for k,v in dic1.items():
      dic4[k]=v
for k,v in dic2.items():
      dic4[k]=v
for k,v in dic3.items():
      dic4[k]=v
print(dic4)
# Out:
# {1: 10, 2: 20, 3: 30, 4: 40, 5: 50, 6: 60}

# %%
'''Write a Python script to generate and print a dictionary that contains a number (between 1 and n) in 
the form (x, x*x).
Sample Dictionary ( n = 5) :
Expected Output : {1: 1, 2: 4, 3: 9, 4: 16, 5: 25}'''
n = int(input("Enter your number"))
d = dict()
for  i in range(1, n + 1):
      d[i]=i*i
print(d)
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25}

# %%
'''Write a Python program to combine two dictionary by adding values for common keys.
d1 = {'a': 100, 'b': 200, 'c':300}
d2 = {'a': 300, 'b': 200, 'd':400}
Sample output: Counter({'a': 400, 'b': 400, 'd': 400, 'c': 300}'''
d1 = {'a': 100, 'b': 200, 'c':300}
d2 = {'a': 300, 'b': 200, 'd':400}
d3 = {}
for i in d1.keys():
   if i in d2.keys():
        d3[i] = d1[i]+d2[i]
   else:
       d3[i]
print(d3)
# Out:
# {'a': 400, 'b': 400, 'd': 400}

# %%
d1 = {'a': 100, 'b': 200, 'c':300}
d2 = {'a': 300, 'b': 200, 'd':400}
d3 = {}
for k in d1.keys() | d2.keys():
    d3[k] = d1.get(k, 0) + d2.get(k, 0)

print(d3)
# Out:
# {'a': 400, 'b': 400, 'd': 400, 'c': 300}

# %%
'''Write a Python program to print all distinct values in a dictionary.
Sample Data : [{"V":"S001"}, {"V": "S002"}, {"VI": "S001"}, {"VI": "S005"}, {"VII":"S005"},
{"V":"S009"},{"VIII":"S007"}]
Expected Output : Unique Values: {'S005', 'S002', 'S007', 'S001', 'S009'}'''

dict1 = [{"V":"S001"}, {"V": "S002"}, {"VI": "S001"}, {"VI": "S005"}, {"VII":"S005"},
{"V":"S009"},{"VIII":"S007"}]
s = set()
for i in dict1:
      for j in i.values():
            s.add(j)
print(s)
# Out:
# {'S005', 'S007', 'S001', 'S002', 'S009'}

# %%
'''Write a Python program to combine values in a list of dictionaries.
Sample data: [{'item': 'item1', 'amount': 400}, {'item': 'item2', 'amount': 300},
{'item': 'item1', 'amount': 750}]
Expected Output: Counter({'item1': 1150, 'item2': 300})'''

dict1= [{'item': 'item1', 'amount': 400}, {'item': 'item2', 'amount': 300},
{'item': 'item1', 'amount': 750}]
dict2 = {}
for i in dict1:
      key = i['item']
      val = i['amount']
      if key in dict2:
            dict2[key]=dict2[key]+val
      else:
            dict2[key]=val
print(dict2)
# Out:
# {'item1': 1150, 'item2': 300}

# %%
s = input()
dict1 = {}
for i in s:
      if i in dict1:
            dict1[i]=dict1[i]+1
      else:
            dict1[i]=1
print(dict1)
# Out:
# {'h': 1, 'e': 1, 'l': 2, 'o': 1}

# %%
s = input()
s = s.split()
dict1 = {}
for i in s:
      if i in dict1:
            dict1[i]=dict1[i]+1
      else:
            dict1[i]=1
print(dict1)
# Out:
# {'happy': 1}

# %%
'''Write a Python program to filter a dictionary based on values.
Original Dictionary:
{'Cierra Vega': 175, 'Alden Cantrell': 180, 'Kierra Gentry': 165, 'Pierre Cox': 190}
Marks greater than 170:
{'Cierra Vega': 175, 'Alden Cantrell': 180, 'Pierre Cox': 190}'''
dict = {'Cierra Vega': 175, 'Alden Cantrell': 180, 'Kierra Gentry': 165, 'Pierre Cox': 190}
dict1 = {}
for k,v in dict.items():
      if v> 170:
            dict1[k]=v
print(dict1)
# Out:
# {'Cierra Vega': 175, 'Alden Cantrell': 180, 'Pierre Cox': 190}

# %%
'''Write a Python program to convert more than one list to a nested dictionary.
Original strings:
['S001', 'S002', 'S003', 'S004']
['Adina Park', 'Leyton Marsh', 'Duncan Boyle', 'Saim Richards']
[85, 98, 89, 92]
Nested dictionary:
[{'S001': {'Adina Park': 85}}, {'S002': {'Leyton Marsh': 98}}, {'S003': {'Duncan Boyle': 89}}, 
{'S004': {'Saim Richards': 92}}]'''
lst = ['S001', 'S002', 'S003', 'S004']
lst1 = ['Adina Park', 'Leyton Marsh', 'Duncan Boyle', 'Saim Richards']
lst2 = [85, 98, 89, 92]
dict1={}
for i in range(len(lst)):
      dict2={lst[i]:{lst1[i],lst2[i]}}
      lst.append(dict2)
print(lst)
# Out:
# ['S001', 'S002', 'S003', 'S004', {'S001': {85, 'Adina Park'}}, {'S002': {'Leyton Marsh', 98}}, {'S003': {89, 'Duncan Boyle'}}, {'S004': {'Saim Richards', 92}}]
