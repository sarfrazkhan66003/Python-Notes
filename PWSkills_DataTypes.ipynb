# %%
#numerical
x=5

# %%
print(type(x))
# Out:
# <class 'int'>

# %%
price = 26.25
print(price)
# Out:
# 26.25

# %%
num = 3e6
print(num)
# Out:
# 3000000.0

# %%
print(type(num))
# Out:
# <class 'float'>

# %%
z = 4 + 5j
print(z)
# Out:
# (4+5j)

# %%
print(type(z))
# Out:
# <class 'complex'>

# %%
print(abs(-5))
# Out:
# 5

# %%
print(pow(2,3))
# Out:
# 8

# %%
print(round(4.75))
print(round(4.5))
# Out:
# 5
# 4

# %%
nums = [3,1,5,7,9,1]

print(min(nums))
print(max(nums))
print(sum(nums))
# Out:
# 1
# 9
# 26

# %%
name = 'vishwa'
city = "Bangalore"
country = '''India'''

# %%
messag = '''
Hello my dear friends,
this is my learning !
'''

# %%
name = "Vishwa Mohan"

print(name[3])
# Out:
# h

# %%
print(name[12])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-10-2ded1f96cb70> in <cell line: 1>()
# ----> 1 print(name[12])
#
# IndexError: string index out of range

# %%
print(name[-1])
# Out:
# n

# %%
print(name[-3])
# Out:
# h

# %%
str = "Vishwa Mohan"

str[0] = 'X'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-c56aaa8ed846> in <cell line: 3>()
#       1 str = "Vishwa Mohan"
#       2
# ----> 3 str[0] = 'X'
#
# TypeError: 'str' object does not support item assignment

# %%
#concatenation
first_name = "Vishwa"
last_name = "Mohan"

complete_name = first_name +" "+ last_name
print(complete_name)
# Out:
# Vishwa Mohan

# %%
#Length of the string
print(len(complete_name))
# Out:
# 12

# %%
str = 'Vishwa Mohan'

print(str[2:5])
# Out:
# shw

# %%
print(str[2:])
# Out:
# shwa Mohan

# %%
print(str[:7])
# Out:
# Vishwa

# %%
print(str[:])
# Out:
# Vishwa Mohan

# %%
print(str[-9:-4 ])
# Out:
# hwa M

# %%
print(str[-9:9])
# Out:
# hwa Mo

# %%
str = "   vIshwa "
print(str.upper())
print(str.lower())
print(str.capitalize())
print(str.strip())
# Out:
#    VISHWA
#    vishwa
#    vishwa
# vIshwa

# %%
#replace method

str = "Hello dear, I am very good, I am very nice, I am wow"

print(str.replace("I am","We are",2))
# Out:
# Hello dear, We are very good, We are very nice, I am wow

# %%
#Escape character

print("Hello \n Vishwa")
# Out:
# Hello
#  Vishwa

# %%
print("Vishwa\tMohan")
# Out:
# Vishwa	Mohan

# %%
print("Vishwa \"Mohan\"")
# Out:
# Vishwa "Mohan"

# %% [markdown]
# Learning List

# %%
students = ["Mohan", "Vishwa", "Shivani", "Sakshi"]

print(students)
print(type(students))
# Out:
# ['Mohan', 'Vishwa', 'Shivani', 'Sakshi']
# <class 'list'>

# %%
list2 = list(students)
print(list2)
# Out:
# ['Mohan', 'Vishwa', 'Shivani', 'Sakshi']

# %%
list3 = list("Vishwa")
print(list3)
# Out:
# ['V', 'i', 's', 'h', 'w', 'a']

# %%
list4 = list((3,4,"Vishwa"))
print(list4)
# Out:
# [3, 4, 'Vishwa']

# %%
#Accessing the elements of the list
l1 = [1,3,9,2,5,6,7]
print(l1[3])
print(l1[-6])
# Out:
# 2
# 3

# %%
arr = [ 3,2,1,5,9]

arr.append(11)
print(arr)
# Out:
# [3, 2, 1, 5, 9, 11]

# %%
arr.insert(3,43)
print(arr)
# Out:
# [3, 2, 1, 43, 5, 9, 11]

# %%
l1 =  [1,2]
l2 = ["Vishwa", "Mohan"]
l1.extend(l2)
print(l1)
# Out:
# [1, 2, 'Vishwa', 'Mohan']

# %%
#Remove elements from the list

# %%
arr = [3,5,2,1,9]
arr.remove(1)
print(arr)
# Out:
# [3, 5, 2, 9]

# %%
arr= [3,5,2,1,9,1,8,1]
arr.remove(1)
print(arr)
# Out:
# [3, 5, 2, 9, 1, 8, 1]

# %%
arr = [3,1,7,9,11,23,45]
print(arr.pop(2))
print(arr)
# Out:
# 7
# [3, 1, 9, 11, 23, 45]

# %%
students = ['a' , 'b', 'c' , 'd','e']

students[3]='f'
print(students)
# Out:
# ['a', 'b', 'c', 'f', 'e']

# %%
students[1:4] = 'm','n'

print(students)
# Out:
# ['a', 'm', 'n', 'e']

# %%
l1 = [1,2,3,4,5]
l1.reverse()
print(l1)
# Out:
# [5, 4, 3, 2, 1]

# %%
l1_copy = l1.copy()
print(l1_copy)

print(id(l1_copy), id(l1))
# Out:
# [5, 4, 3, 2, 1]
# 135033392082624 135033391993664

# %%
l1.sort()

print(l1)
# Out:
# [1, 2, 3, 4, 5]

# %%
#Tuple
tup1 = (3,6,1,9,10)
print(tup1)
print(type(tup1))
# Out:
# (3, 6, 1, 9, 10)
# <class 'tuple'>

# %%
t1 = tuple([1,2,4])
print(t1)
# Out:
# (1, 2, 4)

# %%
t2 = tuple("Vishwa")
t3 = tuple(tup1)

print(t2,t3)
# Out:
# ('V', 'i', 's', 'h', 'w', 'a') (3, 6, 1, 9, 10)

# %%
t = (35,)

print(type(t))
# Out:
# <class 'tuple'>

# %%
fruits = ('apple','mango','banana','apple','mango','apple', 'strawberry')

print(fruits.count('jackfruit'))
# Out:
# 0

# %%
print(fruits.index('jackfruit'))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-735eaf9e0011> in <cell line: 1>()
# ----> 1 print(fruits.index('jackfruit'))
#
# ValueError: tuple.index(x): x not in tuple

# %%
print(fruits.index('mango'))
# Out:
# 1

# %%
print(len(fruits))
# Out:
# 7

# %%
fruits = ('apple','mango','banana','apple','mango','apple', 'strawberry')

# %%
print(fruits[3])
print(fruits[-3])
# Out:
# apple
# mango

# %%
fruits[3] = 'Jackfruit'
print(fruits)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-12a76e4d7578> in <cell line: 1>()
# ----> 1 fruits[3] = 'Jackfruit'
#       2 print(fruits)
#
# TypeError: 'tuple' object does not support item assignment

# %%
#slicing
fruits = ('apple','mango','banana','apple','mango','apple', 'strawberry')

print(fruits[2:7])
# Out:
# ('banana', 'apple', 'mango', 'apple', 'strawberry')

# %% [markdown]
# Boolean

# %%
print(True)
print(False)
# Out:
# True
# False

# %% [markdown]
# Dictionary

# %%
------
print(students_details)
print(type(students_details))
# Out:
# {'name': 'Vishwa', 'age': 21, 'city': 'Bangalore'}
# <class 'dict'>

# %%
dict1 = {1:"Vishwa" , 2:"Mohan" , True : "Love"}
print(dict1)
# Out:
# {1: 'Love', 2: 'Mohan'}

# %%
dict1 = {3:"Vishwa" , 2:"Mohan" , True : "Love"}
print(dict1)
# Out:
# {3: 'Vishwa', 2: 'Mohan', True: 'Love'}

# %%
#Dictionary constructor methods
dict1 = dict(name="Vishwa", age="Mohan", True="Love")
# Out:
#   File "<ipython-input-25-a3502ec24a58>", line 2
#     dict1 = dict(name="Vishwa", age="Mohan", True="Love")
#                                              ^
# SyntaxError: cannot assign to True

# %%
dict1 = dict(name="Vishwa", age="Mohan")
print(dict1)
print(type(dict1))
# Out:
# {'name': 'Vishwa', 'age': 'Mohan'}
# <class 'dict'>

# %%
#Access the elements of the dictionary
students_details = {'name':'Vishwa' , 'age':21, 'city':"Bangalore"}

print(students_details['name'])

print(students_details['city'])
# Out:
# Vishwa
# Bangalore

# %%
print(students_details.keys())
print(students_details.values())
print(students_details.items())
# Out:
# dict_keys(['name', 'age', 'city'])
# dict_values(['Vishwa', 21, 'Bangalore'])
# dict_items([('name', 'Vishwa'), ('age', 21), ('city', 'Bangalore')])

# %% [markdown]
# How do we add elements in the dictionary | key,value

# %%
students_details = {'name':'Vishwa' , 'age':21, 'city':"Bangalore"}

students_details['country'] = "India"

print(students_details)
# Out:
# {'name': 'Vishwa', 'age': 21, 'city': 'Bangalore', 'country': 'India'}

# %%
students_details = {'name':'Vishwa' , 'age':21, 'city':"Bangalore"}

marks_details = {'English': 100, 'Maths':78, 'Science':92}

students_details.update(marks_details)

print(students_details)
# Out:
# {'name': 'Vishwa', 'age': 21, 'city': 'Bangalore', 'English': 100, 'Maths': 78, 'Science': 92}

# %%
#Remove the elements from the dictionary
print(students_details.pop('city'))
print(students_details)
# Out:
# Bangalore
# {'name': 'Vishwa', 'age': 21, 'English': 100, 'Maths': 78, 'Science': 92}

# %%
print(students_details.popitem())
print(students_details)
# Out:
# ('Science', 92)
# {'name': 'Vishwa', 'age': 21, 'English': 100, 'Maths': 78}

# %%
del students_details['age']
print(students_details)
# Out:
# {'name': 'Vishwa', 'English': 100, 'Maths': 78}

# %%
students_details.clear()
print(students_details)
# Out:
# {}

# %% [markdown]
# Set datatyps

# %%
my_set = {1,2,3,5}
print(my_set)
print(type(my_set))
# Out:
# {1, 2, 3, 5}
# <class 'set'>

# %%
s1 = {1,4,5,2,1,9,7,4,1}
print(s1)
# Out:
# {1, 2, 4, 5, 7, 9}

# %%
s2 = set()
print(s2)
# Out:
# set()

# %%
s3 = set({5,6,7})
print(s3)
# Out:
# {5, 6, 7}

# %%
#Add
s = set()

s.add(5)
s.add(13)
s.add(5)
s.add(12)
print(s)
# Out:
# {13, 12, 5}

# %%
#Remove

s1 = {3,9,7,4}
print(s1.discard(7))
print(s1)
# Out:
# None
# {9, 3, 4}

# %%
s1.remove(12)
print(s1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-48-8b9f5218b5d6> in <cell line: 1>()
# ----> 1 s1.remove(12)
#       2 print(s1)
#
# KeyError: 12

# %% [markdown]
# FrozenSet : Immutable set

# %%
fs = frozenset([1,2,3])
print(fs)
print(type(fs))
# Out:
# frozenset({1, 2, 3})
# <class 'frozenset'>

# %%
fs2 = frozenset({1,2,3})
print(fs2)
# Out:
# frozenset({1, 2, 3})

# %%
dict1 = {fs2 : "Vishwa"}
print(dict1)
# Out:
# {frozenset({1, 2, 3}): 'Vishwa'}

# %%
#Implicit typecasting

x = 5
y = 6.5
result = x+y
print(result)
# Out:
# 11.5

# %%
y='10'
print(type(y))
int_y = int(y)
print(type(int_y))
# Out:
# <class 'str'>
# <class 'int'>

# %%
str()
int()
float()

# %%
data = 'one'

print(int(data))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-56-b6c67bdd2672> in <cell line: 3>()
#       1 data = 'one'
#       2
# ----> 3 print(int(data))
#
# ValueError: invalid literal for int() with base 10: 'one'
