# %% [markdown]
# # 31/10/2023

# %% [markdown]
# # Slicing

# %%
myString = "Hello"
print(myString)
# Out:
# Hellos

# %%
myString = "Hello"
#Print first Character 
print(myString[0])
#Print last Character using negative index
print(myString[-1])
#slicing 2nd to 5th Character
print(myString[3:25])
# Out:
# H
# s
# los

# %%
"This,will,split,all,words,in,a,last".split("s")
# Out:
# ['Thi', ',will,', 'plit,all,word', ',in,a,la', 't']

# %%
"This,will,split,all,words,in,a,last".split(sep='s',maxsplit=2)
# Out:
# ['Thi', ',will,', 'plit,all,words,in,a,last']

# %%
' '.join(['This','will','split','all','word','in','a','list'])
# Out:
# 'This will split all word in a list'

# %%
"Good Morning".find("o")
# Out:
# 1

# %%
s1 = "Bad Morning"
s2 = s1.replace("Bad","Good")
print(s1)
print(s2)
# Out:
# Bad Morning
# Good Morning

# %%
x = input("Enter a String")
s = x[-1::-1]
if s == x:
      print("String is Palindrome")
else:
      print("String is not Palindrome")
# Out:
# String is Palindrome

# %%
myStr = "Madam"
#Convert Entire String to either lower or upper
if myStr[:].upper()==myStr[::-1].upper():
      print("Palindrome")
else:
      print("Not Palindrome")
# Out:
# Palindrome

# %%
s = input("Enter Your Character")
lst = []
for i in range(len(s)):
      if s[i] not in lst:
            lst.append(s[i])
print(lst)
# Out:
# ['H', 'a', 'p', 'y', ' ', 'C', 'o', 'd', 'i', 'n', 'g', 'T', 'h', 'k', 'e', 'r']

# %%
s = input("Enter Your Character")
lst = []
count = 0
for i in range(len(s)):
      if s[i] not in lst:
            count+=1
            lst.append(s[i])
print(lst)

# %% [markdown]
# # Home Work

# %%
# Write a Python program to get a string made of the first 2 and last 2 characters of a given string. 
# If the string length is less than 2, return the empty string instead.
# Sample String : 'w3resource'
# Expected Result : 'w3ce'
myStr= 'w3resource'
s = myStr[0:2] +myStr[-2:]
print(s)
# Out:
# w3ce

# %%
# Write a Python program to get a string from a given string where all occurrences of its first char have been changed to '$', except the first char itself.
# Sample String : 'restart'
# Expected Result : 'resta$t'
s = 'restart'
s2 = s[5]
s = s.replace(s2,'$')
s = s2 + s[1:]
print(s)
# Out:
# resta$t

# %%
# Write a Python program to get a single string from two given strings, separated by a space and swap the first two characters of each string.
# Sample String : 'abc', 'xyz'
# Expected Result : 'xyc abz'
s = "abc"
s1 = "xyz"
s2 = s[:-1] + s1 [-1:]
s3 = s1[:-1] + s[-1:]
s4 = s3 + " " + s2
print(s4)
# Out:
# xyc abz

# %%
# Write a Python program to calculate the length of a string.
s = input("Enter a Name")
count = 0
for i in range(len(s)):
      count+=1
print(count)
# Out:
# 7

# %%
# Write a Python program to count the number of characters (character frequency) in a string.
# Sample String : google.com'
# Expected Result : {'g': 2, 'o': 3, 'l': 1, 'e': 1, '.': 1, 'c': 1, 'm': 1}

# %%
 #Write a Python program to add 'ing' at the end of a given string (length should be at least 3). If the given string already ends with 'ing', add 'ly' instead. If the string length of the given string is less than 3, leave it unchanged.
#Sample String : 'abc'
#Expected Result : 'abcing'
#Sample String : 'string'
# Expected Result : 'stringly'
s = input("Enter a Name")
i = s[len(s)-3:]
print(i)
print(s.find("ing"))
if s[len(s)-3:] == "ing":
      s=s + "ly"
#if s.find("ing")==-1:
      #s=s+"ing"
elif s.find("ing")!=(len(s)-3):
      s = s + "ing"
elif s.find("ing")==-1:
      s = s + "ing"
print(s)
# Out:
# ing
# 3
# stringingingly

# %%
s = input()
if len(s)>2:
      if s[-3:]=="ing":
            s+="ly"
      else:
            s+="ing"
print(s)
# Out:
# stringingly

# %% [markdown]
# # 02/11/2023

# %%
#Problem: Take a sentence as input and count the number of words.
#Input: "Hello World, how are you?"
#Output: 5
s = "Hello World, how are you?"
len(s.split())
# Out:
# 5

# %%
# Problem: Take a string as input and count the number of vowels (a, e, i, o, u) in it.
# Input: "Hello"
# Output: 2
s = input()
count = 0
for i in s:
     if(i == 'a' or i == 'e' or i == 'i' or i == 'o' or i == 'u'):
          count+=1
print(count)
# Out:
# 2

# %%
#Problem: Take a string as input and replace all spaces with underscores.
#Input: "Hello World"
#Output: "Hello_World"
s = "Hello World"
s.replace(' ','_')
# Out:
# 'Hello_World'

# %%
#Problem: Take two strings as input and check if one is a rotation of the other.
#Input: "waterbottle", "erbottlewat"
#Output: "Rotation"
s = "waterbottle"
s1 = "erbottlewat" 
s2  = s+s1
if s in s2:
      print("Rotation")
else:
      print("Not Rotation")
# Out:
# Rotation

# %%
def is_rotation(str1, str2):
    if len(str1) != len(str2):
        return "Not a Rotation"

    # Concatenate str1 with itself
    concatenated = str1 + str1

    # Check if str2 is a substring of the concatenated string
    if str2 in concatenated:
        return "Rotation"
    else:
        return "Not a Rotation"

# Input strings
str1 = input("Enter the first string: ")
str2 = input("Enter the second string: ")

result = is_rotation(str1, str2)
print(result)
# Out:
# Rotation

# %% [markdown]
# # Home Work

# %%
# Write a Python program to find the first appearance of the substrings 'not' and 'poor' in a given string. 
# If 'not' follows 'poor', replace the whole 'not'...'poor' substring with 'good'. Return the resulting string.
#Sample String : 'The lyrics is not that poor!'
##'The lyrics is poor!'
#Expected Result : 'The lyrics is good!'
#'The lyrics is poor!'
s = input('Enter a string ')
count = 0
count = s.find('not')
count1 = s.find('poor')
print(count,count1)
#if(count>=0 and count1>=0):
s= s.replace(s[count:count1+4],'good')
print(s)
# Out:
# 14 23
# The lyrics is good!

# %%
# Write a Python function that takes a list of words and return the longest word and the length of the longest one.
# Sample Output:
# # Longest word: Exercises
# Length of the longest word: 9
s = input()
count = 1
for i in range(len(s)):
      if len(s)>count:
            count=len(s)
print(count)
# Out:
# 9

# %%
# Write a Python program to remove the nth index character from a nonempty string.
s = input()
n = len(s)
print(n)
n1 = int(input())
s1 = s[:n]
s2 = s[n+1:]
s3 = s1+s2
print("Str after removing chars at the index",n1,"is",s3)
# Out:
# 11
# Str after removing chars at the index 5 is Programming

# %%
# Write a Python program to change a given string to a newly string where the first and last chars have been exchanged.
s = input()
start = s[0]
end = s[-1]
swapp = end + s[1:-1] + start
print(swapp)
# Out:
# zarfraS

# %%
# Write a Python program to remove characters that have odd index values in a given string.
s = input()
s1 = " "
for i in range(len(s)):
      if i%2!=0:
            s1=s1+s[i]
print(s1)
# Out:
#  afa

# %%
# Write a Python program to count the occurrences of each word in a given sentence.
s = input()
print(s.upper())
print(s.lower())
# Out:
# I AM A CODER
# i am a coder

# %%
# Write a Python program that accepts a comma-separated sequence of words as input and prints 
# the distinct words in sorted form (alphanumerically).
# Sample Words : red, white, black, red, green, black
# Expected Result : black, green, red, white,red
s = input()
s1 = [s1 for s1 in s.split(",")]
print(",".join(sorted(list(set(s1)))))
# Out:
#  black, green, red, white,red

# %%
items = input("Input comma separated sequence of words")
words = [word for word in items.split(",")]
print(",".join(sorted(list(set(words)))))
# Out:
#  black, green, red, white,red

# %%
# Write a Python function to create an HTML string with tags around the word(s).
# Sample function and result :
# add_tags('i', 'Python') -> '<i>Python</i>'
# add_tags('b', 'Python Tutorial') -> '<b>Python Tutorial </b>'
s = ('i', 'Python')
s1 = " "

# %%
# Write a Python function to insert a string in the middle of a string.
#Sample function and result :
#insert_sting_middle('[[]]<<>>', 'Python') -> [[Python]]
#insert_sting_middle('{{}}', 'PHP') -> {{PHP}}

# %% [markdown]
# # 07/11/2023

# %%
# Write a Python program to swap commas and dots in a string.
# Sample string: "32.054,23"
# Expected Output: "32,054.23"
s = "32.054,23"
s2=s.replace(".","$")
s3=s2.replace(",",".")
s4=s3.replace("$",",")
print(s4)
# Out:
# 32,054.23

# %%
s = "32.054,23"
s1 = " "
for i in s:
      if i==".":
            s1+=","
      elif i==",":
            s1+="."
      else:
            s1+=i
print(s1)
# Out:
#  32,054.23

# %%
#Write a Python function to convert a given string to all uppercase 
# if it contains at least 2 uppercase characters in the first 4 characters.
s = input()
count = 0
for i in s[:4]:
      if(i.upper()==i):
            count+=1
            if count>=2:
                  print(s.upper())
            else:
                  print(s)
# Out:
# asRHfngmjgjgf
# ASRHFNGMJGJGF

# %%
s = "This is Python Program"
s = s.split()
for i in range(len(s)):
      temp=s[i]
      temp=temp[::-1]
      s[i]=temp
s = " ".join(s)
print(s)
# Out:
# sihT si nohtyP margorP

# %% [markdown]
# # Home Work

# %%
# Write a Python function to get a string made of 4 copies of the last two characters of a specified string (length must be at least 2).
# Sample function and result :
# insert_end('Python') -> onononon
# insert_end('Exercises') -> eseseses
str = input()
str1 = str[-2:]
print(str1*4)
# Out:
# onononon

# %%
# Write a Python function to get a string made of the first three characters of a specified string. 
# If the length of the string is less than 3, return the original string.
# Sample function and result :
# first_three('ipy') -> ipy
# first_three('python') -> pyt
str = input()
print(str[:3] if len(str)>3 else str)
# Out:
# Pyt

# %%
str = input()
if(len(str)<=3):
      print(str)
else:
      print(str[:3])
# Out:
# Pyt

# %%
# Write a Python program to get the last part of a string before a specified character.
#  https://www.w3resource.com/python-exercises
# https://www.w3resource.com/python
str = "https://www.w3resource.com/python-exercises"
print(str.split("/",1))
print(str.split("-",1)[0])
# Out:
# ['https:', '/www.w3resource.com/python-exercises']
# https://www.w3resource.com/python

# %%
#  Write a Python function to reverse a string if its length is a multiple of 4.
str = input()
print(''.join(reversed(str)))
# Out:
# ybuR

# %%
# Write a Python function to convert a given string to all 
# uppercase if it contains at least 2 uppercase characters in the first 4 characters.
s = input()
count = 0
for i in s[:4]:
      if(i.upper()==i):
            count+=1
            if count>=2:
                  print(s.upper())
            else:
                  print(s)
# Out:
# PyThon
# PYTHON

# %%
# Write a Python program to sort a string lexicographically.
s = 'w3resource'
print(sorted(sorted(s)))
# Out:
# ['3', 'c', 'e', 'e', 'o', 'r', 'r', 's', 'u', 'w']

# %%
# Given two strings S and P. Find the smallest window in the string S consisting of all the characters
# (including duplicates) of the string P.
# Return "-1" in case there is no such window present. 
# In case there are multiple such windows of same length, 
# return the one with the least starting index.
# Note : All characters are in Lowercase alphabets. 

# Input: S = "timetopractice" & P = "toc"
# Output: toprac

# %%
# Write a Python program to remove a newline in Python.
s = "Python Exersice\n"
count=0
for i in s[-1:]:
      s.remove(i)
print(s)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# d:\Python\String.ipynb Cell 53 line 5
#       <a href='vscode-notebook-cell:/d%3A/Python/String.ipynb#Y103sZmlsZQ%3D%3D?line=2'>3</a> count=0
#       <a href='vscode-notebook-cell:/d%3A/Python/String.ipynb#Y103sZmlsZQ%3D%3D?line=3'>4</a> for i in s[-1:]:
# ----> <a href='vscode-notebook-cell:/d%3A/Python/String.ipynb#Y103sZmlsZQ%3D%3D?line=4'>5</a>       s.remove(i)
#       <a href='vscode-notebook-cell:/d%3A/Python/String.ipynb#Y103sZmlsZQ%3D%3D?line=5'>6</a> print(s)
#
# AttributeError: 'str' object has no attribute 'remove'

# %%
#24 Write a Python program to check whether a string starts with specified characters.
str = "W3resources"
print(str.startswith("W3r"))
# Out:
# True

# %%
# You are given two strings of equal lengths, s1 and s2. The task is to check if s2 is a rotated version of the string s1.

# Note: The characters in the strings are in lowercase.

# Input:geeksforgeeks
#output :forgeeksgeeks
s = "geeksforgeeks"
s=s.split()
for i in range(len(s)):
      temp=s[i]
      temp=temp[::-1]
      s[i]=temp
      s=" ".join(s)
print(s)
# Out:
# skeegrofskeeg

# %%
s1='geeksforgeeks'
s2='forgeeksgeeks'
print(len(s1)==len(s2) and s1 in 2*s2)
# Out:
# True

# %%
s1='geeksforgeeks'
s2='forgeeksgeeks'
if len(s1)!=len(s2):
      print(False)
s3=s1+s2
if s2 in s3:
      print(True)
else:
      print(False)
# Out:
# True
