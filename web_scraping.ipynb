# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
data = [
        ["Noise Watch","4.1 out of 5 star","3000","1500"],
        ["Firebolt Watch","4.1 out of 5 star","3000","1500"]
        ]
df = pd.DataFrame(data,columns = ["Product Name","Rating","Review Count","Price"])

# %%
df
# Out:
#      Product Name             Rating Review Count Price
# 0     Noise Watch  4.1 out of 5 star         3000  1500
# 1  Firebolt Watch  4.1 out of 5 star         3000  1500

# %%
url = "https://www.amazon.in/gp/bestsellers/watches/ref=zg_bs_nav_watches_0"
response = requests.get(url)
content = response.content
soup = BeautifulSoup(content)
heading_html = soup.find('h1',attrs={"class": "a-size-large a-spacing-medium a-text-bold"})
heading_html.get_text()

product_cards = soup.find_all("div",attrs={"id": "gridItemRoot"})

def get_product_details(product_card):
  name_html = product_card.find("a",attrs={"class": "a-link-normal"})
  if name_html:
    image = name_html.find('img')
    name = image.get('alt')
  else:
    name = ""

  rating_html = product_card.find('i',attrs={"class":"a-icon a-icon-star-small a-star-small-4 aok-align-top"})
  if rating_html:
     rating = rating_html.get_text()
  else:
    rating = ""


  review_html = product_card.find('span',attrs={"class": "a-size-small"})
  if review_html:
     review_count = review_html.get_text()
  else:
    review_count = ""

  aRows_last_div = product_card.find_all('div',attrs={"class": "a-row"})[-1]

  price_html = aRows_last_div.find("span",{"class": "p13n-sc-price"})

  if price_html:
      price = price_html.get_text()

  else:
    price = ""




  return [name,rating,review_count,price ]

# %%
data = []
for product_card in product_cards:
  detail = get_product_details(product_card)
  data.append(detail)

# %%
data
# Out:
# [['Noise Pulse Go Buzz Smart Watch with Advanced Bluetooth Calling, 1.69" TFT Display, SpO2, 100 Sports Mode with Auto Detection',
#   '4.1 out of 5 stars',
#   '39,864',
#   '₹1,299.00'],
#  ['Noise Twist Round dial Smart Watch with Bluetooth Calling, 1.38" TFT Display, up-to 7 Days Battery, 100+ Watch Faces, IP68, H',
#   '4.1 out of 5 stars',
#   '24,482',
#   '₹1,399.00'],
#  ['Fastrack Limitless Glide Advanced UltraVU HD Display|BT Calling|Advance Chipset|85+ Sports Modes & Watchfaces|Voice Assistant',
#   '3.9 out of 5 stars',
#   '8,463',
#   '₹1,399.00'],
#  ['Noise ColorFit Pulse Grand Smart Watch with 1.69"(4.29cm) HD Display, 60 Sports Modes, 150 Watch Faces, Fast Charge, Spo2, St',
#   '4.0 out of 5 stars',
#   '121,433',
#   ''],
#  ['Fire-Boltt Phoenix Ultra Luxury Stainless Steel, Bluetooth Calling Smartwatch, AI Voice Assistant, Metal Body with 120+ Sport',
#   '4.1 out of 5 stars',
#   '71,530',
#   '₹1,799.00'],
#  ['boAt Wave Lite Smart Watch w/ 1.69" (4.2 cm) HD Display, Sleek Metal Body, HR & SpO2 Level Monitor, 140+ Watch Faces, Activit',
#   '3.9 out of 5 stars',
#   '74,635',
#   '₹999.00'],
#  ['Casio Vintage A158WA-1DF Black Digital Dial Silver Stainless Steel Band D011',
#   '',
#   '42,931',
#   '₹1,695.00'],
#  ['Fire-Boltt Talk 2 Bluetooth Calling Smartwatch with Dual Button, Hands On Voice Assistance, 120 Sports Modes, in Built Mic & ',
#   '4.1 out of 5 stars',
#   '43,955',
#   '₹999.00'],
#  ['Samsung Galaxy Fit3 (Gray), 40mm AMOLED Display with Aluminium Body, Comprehensive Fitness and Health Tracking, Upto 13-Day B',
#   '3.9 out of 5 stars',
#   '703',
#   '₹4,244.00'],
#  ['SPIKY 3D Cartoon Kids Analog Watch with LED Luminous 7 Multicolour Glowing Disco Light | 3D Unique Cute Cartoon on Belt | Unb',
#   '4.1 out of 5 stars',
#   '1,944',
#   '₹494.00'],
#  ['Matrix Antique 2.0 Day & Date Softest Silicone Strap Analog Watch for Men & Boys',
#   '4.1 out of 5 stars',
#   '1,341',
#   '₹318.00'],
#  ['Acnos 6 Colours Luminous LED Display Fashionable Children Kids Digital Watches Waterproof Sports Square Electronic Led Watch ',
#   '3.9 out of 5 stars',
#   '567',
#   '₹280.00'],
#  ['Sounce Silicone 22mm Replacement Watch Strap with Metal Buckle Compatible with Boat Xtend, Boat Xtend Pro, Noise Colorfit Pul',
#   '4.2 out of 5 stars',
#   '2,953',
#   '₹299.00'],
#  ['TIMEWEAR Analog Day Date Functioning Stainless Steel Chain Watch for Men',
#   '3.8 out of 5 stars',
#   '13,025',
#   '₹319.00'],
#  ['Fastrack Analog Unisex-Adult Watch',
#   '4.1 out of 5 stars',
#   '12,810',
#   '₹815.00'],
#  ["LEDO Men's and Women's Watch Box Holder Organizer Case In 12 Slots of watches In PU Leather with Black & Gray",
#   '',
#   '1,179',
#   '₹998.00'],
#  ['Casio Youth Series Digital Black Dial Unisex Watch - F-91W-1Q(D002)',
#   '',
#   '9,649',
#   ''],
#  ['Shocknshop Digital Sports Multi Functional Black Dial Watch for Mens Boys -315RED',
#   '3.9 out of 5 stars',
#   '8,675',
#   '₹284.00'],
#  ['Acnos® Premium Brand Digital 4 Colours Square Dial Unisex Wrist Watch for Men Women Pack of 1 (WR)',
#   '3.8 out of 5 stars',
#   '1,338',
#   '₹280.00'],
#  ["TIMEX Analog Men's Watch (Dial Colored Strap)",
#   '4.1 out of 5 stars',
#   '21,551',
#   '₹957.00'],
#  ['Acnos® Premium Brand - A Digital Watch Shockproof Multi-Functional Automatic 5 Color Army Strap Waterproof Digital Sports Wat',
#   '4.1 out of 5 stars',
#   '1,621',
#   '₹284.00'],
#  ['Fastrack Fastfit Quartz Analog Grey Dial Silicone Strap Unisex Watch-NS68011PP08',
#   '4.2 out of 5 stars',
#   '892',
#   '₹895.00'],
#  ['LOUIS DEVIN Silicone Strap Analog Wrist Watch for Men (Black/Blue/Red) | LD-BK054',
#   '4.0 out of 5 stars',
#   '3,363',
#   '₹369.00'],
#  ["IMPERIOUS - THE ROYAL WAY Analogue Women's Watch (Black Dial)",
#   '3.9 out of 5 stars',
#   '8,065',
#   '₹779.00'],
#  ['Acnos® Premium Brand - A Watch Analogue Plain Black Dial Magnet Watch with Gift Bracelet for Women Or Girls and Watch for Gir',
#   '4.1 out of 5 stars',
#   '1,649',
#   '₹299.00'],
#  ['Leather World Watch Box Holder Organizer Case in 6 Slots of Watches for Men and Women with Transparent Display (Blue)',
#   '',
#   '1,316',
#   '₹597.00'],
#  ['Shocknshop LED Luminous Child Kids Children Cute Cartoon Multi Color Lights Watch for Girls -W327',
#   '4.0 out of 5 stars',
#   '724',
#   '₹369.00'],
#  ["SKMEI Men's Watch New Wheels Rolling Creative Fashion Che Youhui League Fans Butterfly Double Snap Gift Wristwatch - 1990",
#   '4.2 out of 5 stars',
#   '971',
#   '₹1,798.00'],
#  ['Joker & Witch Nebula Stainless Steel Band Analog Watch for Women',
#   '3.9 out of 5 stars',
#   '1,182',
#   '₹699.00'],
#  ["Acnos Premium Analogue Women's Rose-Gold Magnet Watch With Rosegold Bracelet With Gift Box - Metal",
#   '4.1 out of 5 stars',
#   '1,631',
#   '₹280.00'],
#  ['LOUIS DEVIN Rose Gold Plated Mesh Chain Analog Wrist Watch for Women (Blue/Green/Brown/Black Dial) | LD-RG173',
#   '4.0 out of 5 stars',
#   '455',
#   '₹349.00'],
#  ["LEDO Men's and Women's Watch Box Holder Organizer Case In 12 Slots of watches In PU Leather with Royal Black color",
#   '',
#   '3,720',
#   '₹898.00'],
#  ['Red Ribbon Pro watch box organizer watch organizer for men and women | watch case | watch storage box organizer | transparent',
#   '4.1 out of 5 stars',
#   '7',
#   '₹599.00'],
#  ['Matrix Kids Edition Spiderman/Barbie/Ben 10 / Marvel Avengers Digital Watch with 24 Image Projection (Boys & Girls)',
#   '3.9 out of 5 stars',
#   '261',
#   '₹229.00'],
#  ["STYLEDOSE Women Analogue Wrist Watches for Women's & Girls&Miss&Ladies Diamond Studded Dial RoseGold Colored Stylish Bracelet",
#   '',
#   '92',
#   '₹399.00'],
#  ["SKMEI Men's Watch New Wheels Rolling Creative Fashion Che Youhui League Fans Butterfly Double Snap Gift Wristwatch - 1787",
#   '4.2 out of 5 stars',
#   '653',
#   '₹1,798.00'],
#  ['CRESTELLO Silicone Strap Analog Wrist Watch for Women (Black/Blue/Green/Brown) | CR-Ck137',
#   '4.0 out of 5 stars',
#   '258',
#   '₹299.00'],
#  ['Titan Smart 3 Premium Smart Watch|1.96" Super AMOLED Display with 410x502 Pixel Resolution|SingleSync BT Calling|NitroFast Ch',
#   '3.8 out of 5 stars',
#   '1,190',
#   '₹4,995.00'],
#  ['Fire-Boltt Dapper’s 54.61 mm (2.15 inch) IPS Big Screen, GPS Tracking, Compass, Wireless Charging, Bluetooth Calling, 105 Spo',
#   '3.9 out of 5 stars',
#   '43,325',
#   '₹1,999.00'],
#  ['LOUIS DEVIN Rose Gold Plated Mesh Chain Analog Wrist Watch for Women (Black/Blue/Rose Gold Dial) | RG162',
#   '4.0 out of 5 stars',
#   '571',
#   '₹349.00'],
#  ["NIBOSI Women Stainless Steel Watches Analog Rose Gold Band and Square Dial Women's Watch for Girls&Miss&Ladies Diamond Studde",
#   '4.2 out of 5 stars',
#   '1,735',
#   '₹2,599.00'],
#  ['Matrix Kids Edition Spiderman/Frozen/Ben 10 / Hello Kitty/Marvel Avengers Digital Watch for Kids with Disco LED Lights (Boys ',
#   '3.8 out of 5 stars',
#   '1,954',
#   '₹289.00'],
#  ['Fossil Decker Brown Watch', '4.2 out of 5 stars', '5,668', '₹5,097.00'],
#  ['Carlington Analog-Digital Sports Watch: Chronograph, Dual Time, Alarm, Stopwatch, Water-Resistant, Shock-Resistant, Back Ligh',
#   '4.0 out of 5 stars',
#   '253',
#   '₹1,199.00'],
#  ['Fastrack Limitless Fs2 with 1.91" Super Ultravu Display|Bt Calling|Advanced ATS Chipset|Functional Crown|320X385 Pixel Resolu',
#   '4.0 out of 5 stars',
#   '4,881',
#   '₹1,999.00'],
#  ['V2A Chronograph Analogue and Digital Sports Watch for Men | Watch for Men | Wrist Watch for Men | Mens Watch | Watch',
# 29  Acnos Premium Analogue Women's Rose-Gold Magne...  4.1 out of 5 stars
# 30  LOUIS DEVIN Rose Gold Plated Mesh Chain Analog...  4.0 out of 5 stars
# 31  LEDO Men's and Women's Watch Box Holder Organi...
# 32  Red Ribbon Pro watch box organizer watch organ...  4.1 out of 5 stars
# 33  Matrix Kids Edition Spiderman/Barbie/Ben 10 / ...  3.9 out of 5 stars
# 34  STYLEDOSE Women Analogue Wrist Watches for Wom...
# 35  SKMEI Men's Watch New Wheels Rolling Creative ...  4.2 out of 5 stars
# 36  CRESTELLO Silicone Strap Analog Wrist Watch fo...  4.0 out of 5 stars
# 37  Titan Smart 3 Premium Smart Watch|1.96" Super ...  3.8 out of 5 stars
# 38  Fire-Boltt Dapper’s 54.61 mm (2.15 inch) IPS B...  3.9 out of 5 stars
# 39  LOUIS DEVIN Rose Gold Plated Mesh Chain Analog...  4.0 out of 5 stars
# 40  NIBOSI Women Stainless Steel Watches Analog Ro...  4.2 out of 5 stars
# 41  Matrix Kids Edition Spiderman/Frozen/Ben 10 / ...  3.8 out of 5 stars
# 42                          Fossil Decker Brown Watch  4.2 out of 5 stars
# 43  Carlington Analog-Digital Sports Watch: Chrono...  4.0 out of 5 stars
# 44  Fastrack Limitless Fs2 with 1.91" Super Ultrav...  4.0 out of 5 stars
# 45  V2A Chronograph Analogue and Digital Sports Wa...  3.8 out of 5 stars
# 46  Acnos® Premium Girl's Special Quality Differen...  4.0 out of 5 stars
# 47  SWISSTONE Analog Stainless Steel Silver Plated...  4.0 out of 5 stars
# 48  Vibez by Lifelong Premium Luxury Smartwatch fo...  3.8 out of 5 stars
# 49  Shocknshop Analog Digital Sports Black Dial Mu...  4.0 out of 5 stars
#
#    Review Count      Price
# 0        39,864  ₹1,299.00
# 1        24,482  ₹1,399.00
# 2         8,463  ₹1,399.00
# 3       121,433
# 4        71,530  ₹1,799.00
# 5        74,635    ₹999.00
# 6        42,931  ₹1,695.00
# 7        43,955    ₹999.00
# 8           703  ₹4,244.00
# 9         1,944    ₹494.00
# 10        1,341    ₹318.00
# 11          567    ₹280.00
# 12        2,953    ₹299.00
# 13       13,025    ₹319.00
# 14       12,810    ₹815.00
# 15        1,179    ₹998.00
# 16        9,649
# 17        8,675    ₹284.00
# 18        1,338    ₹280.00
# 19       21,551    ₹957.00
# 20        1,621    ₹284.00
# 21          892    ₹895.00
# 22        3,363    ₹369.00
# 23        8,065    ₹779.00
# 24        1,649    ₹299.00
# 25        1,316    ₹597.00
# 26          724    ₹369.00
# 27          971  ₹1,798.00
# 28        1,182    ₹699.00
# 29        1,631    ₹280.00
# 30          455    ₹349.00
# 31        3,720    ₹898.00
# 32            7    ₹599.00
# 33          261    ₹229.00
# 34           92    ₹399.00
# 35          653  ₹1,798.00
# 36          258    ₹299.00
# 37        1,190  ₹4,995.00
# 38       43,325  ₹1,999.00
# 39          571    ₹349.00
# 40        1,735  ₹2,599.00
# 41        1,954    ₹289.00
# 42        5,668  ₹5,097.00
# 43          253  ₹1,199.00
# 44        4,881  ₹1,999.00
# 45        3,805    ₹799.00
# 46        1,769    ₹280.00
# 47       13,034    ₹299.00
# 48        2,164  ₹1,999.00
# 49        1,033    ₹479.00

# %%
df.to_csv("amazon_watches_collections.cvs")
